# %% [markdown]
# <a href="https://colab.research.google.com/github/sta66y/-license-plate-detection-system-/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/My\ First\ Project.v1i.yolov8 .

# %%
# !ls
# Out:
#  drive			        runs	      yolo26n.pt
# 'My First Project.v1i.yolov8'   sample_data   yolov8s.pt

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="/content/My First Project.v1i.yolov8/data.yaml",
    epochs=100,
    imgsz=640,
    project="/content/drive/MyDrive/yolo_runs"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/yolo_runs/train/weights/best.pt")

results = model.predict(
    source="/content/My First Project.v1i.yolov8/test/images",
    save=True
)
# Out:
# image 1/28 /content/My First Project.v1i.yolov8/test/images/1_img019_png.rf.c98260bc7cf51ce1f745711914778dcc.jpg: 640x640 2 0s, 18.7ms
# image 2/28 /content/My First Project.v1i.yolov8/test/images/1_img022_png.rf.7c050d635610b8568a5e3500a324a591.jpg: 640x640 3 0s, 16.1ms
# image 3/28 /content/My First Project.v1i.yolov8/test/images/1_img055_png.rf.d16f4c7365bb833e515863d9f94c8800.jpg: 640x640 2 0s, 16.1ms
# image 4/28 /content/My First Project.v1i.yolov8/test/images/1_img071_png.rf.e5866a49f6417dc4099bfb0ffb61ac52.jpg: 640x640 2 0s, 16.1ms
# image 5/28 /content/My First Project.v1i.yolov8/test/images/1_img144_png.rf.5963a4010152f88457ab8ee1fc93fce7.jpg: 640x640 1 0, 16.1ms
# image 6/28 /content/My First Project.v1i.yolov8/test/images/1_img240_png.rf.8109021968ee53c38f86ae41ca980b42.jpg: 640x640 2 0s, 16.1ms
# image 7/28 /content/My First Project.v1i.yolov8/test/images/2_img013_png.rf.f46e9aaee2bf7e18850ee7aed06fe765.jpg: 640x640 (no detections), 16.1ms
# ...
