# %% [markdown]
# <a href="https://colab.research.google.com/github/sta66y/-license-plate-detection-system-/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.8 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wiRwVg3yCEZxxMhA5j60")
project = rf.workspace("ilyas-workspace-fev70").project("cvat-rzlad-cfouw")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 135.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cvat+-1 in yolov8:: 100%|██████████| 1190/1190 [00:00<00:00, 2034.58it/s]

# %%
# !ls
# Out:
# cvat+-1  sample_data

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="cvat+-1/data.yaml",
    epochs=100,
    imgsz=640,
    project="/content/drive/MyDrive/yolo_runs"
)
# Out:
# Ultralytics 8.4.33 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/yolo_runs/train/weights/best.pt")

results = model.predict(
    source="/content/drive/testImg",
    save=True
)
# Out:
# image 1/4 /content/drive/testImg/4ddd678c447c9d1cde3cb0e4519661d2 (1).webp: 384x640 4 numbers, 42.2ms
# image 2/4 /content/drive/testImg/6578_img1.jpg: 320x640 1 number, 40.5ms
# image 3/4 /content/drive/testImg/depositphotos_3643951-stock-photo-many-cars-on-road.jpg: 448x640 15 numbers, 43.7ms
# image 4/4 /content/drive/testImg/p8ZQfTgU2f43dexA9qQK.webp: 384x640 (no detections), 13.1ms
# Speed: 2.1ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
